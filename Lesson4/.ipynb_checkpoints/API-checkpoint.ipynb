# %%
import requests
import unittest
import re
from bs4 import BeautifulSoup
import pandas as pd
from requests.auth import HTTPBasicAuth

def getUsersFromPage(url):
    result = requests.get(url)
    result.status_code
    print( "Getting data from ")
    users=[]
    if result.status_code == 200:
        soup= BeautifulSoup(result.content, "html.parser")
        table=soup.find("table")
        trs=table.findAll("tr")[1:]
        for tr in trs: 
            td= tr.findAll("td")[0]
            a= td.find("a")
            users.append(a.text)
    return users
        
def getStarsFromApi(users):
    stars=[]
    meanByUser=dict()
    for user in users:
        userUrl= api_url+user+"/repos"
        result = requests.get(userUrl, headers=headers)
        if result.status_code == 200:
            data= result.json()
            numberOfRepos= len(data)
            stargazers=0
            
            for repo in data:
                stargazers+=repo["stargazers_count"]
            meanByUser[user]=stargazers/numberOfRepos
    return meanByUser

def getStarsfromRepo(repos):
    stars=[]
    for repo in repos:
        result = requests.get(repo,  auth=HTTPBasicAuth('user'))
        if result.status_code == 200:
            data= result.json()
            stars.append(data["stargazers_url"])
    return stars

website = "https://gist.github.com/paulmillr/2657075"
api_url = "https://api.github.com/users/"




api_token="68a26c325805e72196a11255997f6c7ba53dcb5f"
headers = {'Authorization': 'token %s' % api_token}


users=getUsersFromPage(website)
means= getStarsFromApi(users)
meansSorted=sorted(means.items(), key=lambda x: x[1])


print(meansSorted)
# Out:
# Getting data from
# ok
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-9-1eca9c18a56a> in <module>()
#      60
#      61 users=getUsersFromPage(website)
# ---> 62 means= getStarsFromApi(users)
#      63 meansSorted=sorted(means.items(), key=lambda x: x[1])
#      64
#
# <ipython-input-9-1eca9c18a56a> in getStarsFromApi(users)
#      36             for repo in data:
#      37                 stargazers+=repo["stargazers_count"]
# ---> 38             meanByUser[user]=stargazers/numberOfRepos
#      39     return meanByUser
#      40
#
# ZeroDivisionError: division by zero
